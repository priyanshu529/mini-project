# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("career_dataset_5000.csv")

# %%
df.head()
# Out:
#    Programming  Machine Learning  Data Analysis  Cybersecurity  Networking  \
# 0            9                 6              7              6           7
# 1            5                 3              6             10          10
# 2            5                 3              6              6           7
# 3            8                 5             10              6           6
# 4            5                 6              3              9          10
#
#    UI/UX Design  Communication  Problem Solving  \
# 0             4              7               10
# 1             4              4                8
# 2             2              7                6
# 3             5              5                9
# 4             4              7                7
#
#                             Career
# 0                  Software tester
# 1              Networking Engineer
# 2     Application Support Engineer
# 3                  Software tester
# 4  Information Security Specialist

# %%
df['Career'].unique()
# Out:
# array(['Software tester', 'Networking Engineer',
#        'Application Support Engineer', 'Information Security Specialist',
#        'API Specialist', 'AI ML Specialist', 'Customer Service Executive',
#        'Hardware Engineer', 'Database Administrator',
#        'Software Developer', 'Cyber Security Specialist',
#        'Business Analyst', 'Graphics Designer', 'Helpdesk Engineer',
#        'Project Manager', 'Technical Writer'], dtype=object)

# %%
role_skills_detailed = {
    "Database Administrator": [
        "SQL", "MySQL", "PostgreSQL", "Oracle", "Database Design", "Normalization",
        "Backup and Recovery", "Stored Procedures", "Performance Tuning",
        "Data Modeling", "Security Management", "NoSQL", "MongoDB"
    ],
    
    "Hardware Engineer": [
        "Computer Architecture", "Microprocessors", "Embedded Systems", "C Programming",
        "PCB Design", "VHDL", "Verilog", "Circuit Design", "Digital Electronics",
        "Troubleshooting", "Hardware Testing"
    ],
    
    "Application Support Engineer": [
        "SQL", "Linux", "Shell Scripting", "Debugging", "Monitoring Tools",
        "Incident Management", "Customer Support", "Networking Basics",
        "Troubleshooting", "API Logs", "Performance Analysis"
    ],
    
    "Cyber Security Specialist": [
        "Network Security", "Ethical Hacking", "Penetration Testing", "Firewalls",
        "Linux", "Python", "Cryptography", "Security Audits", "Incident Response",
        "SIEM Tools", "Risk Assessment", "IDS/IPS"
    ],
    
    "Networking Engineer": [
        "Networking Fundamentals", "CCNA", "Routing and Switching", "Firewalls",
        "LAN/WAN", "VPN Configuration", "TCP/IP", "DNS", "DHCP", "Network Monitoring",
        "Troubleshooting", "Cabling", "Load Balancing"
    ],
    
    "Software Developer": [
        "C", "C++", "Java", "Python", "Git", "OOP", "Data Structures", "Algorithms",
        "Debugging", "Unit Testing", "Agile", "REST APIs", "SQL", "System Design"
    ],
    
    "API Specialist": [
        "REST", "SOAP", "GraphQL", "Postman", "JSON", "OAuth", "API Security",
        "Swagger", "API Documentation", "Microservices", "Integration", "Python", "Node.js"
    ],
    
    "Project Manager": [
        "Project Planning", "Agile", "Scrum", "JIRA", "Communication", "Team Management",
        "Risk Management", "Budgeting", "SDLC", "Stakeholder Management", "Documentation"
    ],
    
    "Information Security Specialist": [
        "Information Security", "Network Security", "Cyber Laws", "Vulnerability Assessment",
        "Ethical Hacking", "Risk Management", "Security Audits", "Compliance",
        "Incident Response", "Encryption", "Firewalls", "Cloud Security"
    ],
    
    "Technical Writer": [
        "Technical Documentation", "Research", "Communication", "MS Word", "Markdown",
        "Version Control", "API Documentation", "Software Guides", "Editing", "Proofreading"
    ],
    
    "AI ML Specialist": [
        "Python", "TensorFlow", "Keras", "PyTorch", "Scikit-learn", "Machine Learning",
        "Deep Learning", "NLP", "Computer Vision", "Data Preprocessing", "Model Evaluation",
        "Statistics", "Mathematics", "Feature Engineering"
    ],
    
    "Software tester": [
        "Manual Testing", "Automation Testing", "Selenium", "JUnit", "TestNG",
        "Bug Tracking", "Agile Testing", "API Testing", "Regression Testing",
        "JIRA", "SDLC", "STLC"
    ],
    
    "Business Analyst": [
        "Requirements Analysis", "MS Excel", "SQL", "Data Visualization", "Power BI",
        "Tableau", "Communication", "Process Mapping", "Documentation", "UML",
        "Business Intelligence", "Problem Solving"
    ],
    
    "Customer Service Executive": [
        "Communication", "CRM Tools", "Email Etiquette", "Problem Solving",
        "Customer Relationship Management", "Multitasking", "Microsoft Office",
        "Helpdesk Software", "Conflict Resolution", "Soft Skills"
    ],
    
    "Helpdesk Engineer": [
        "Technical Support", "Networking Basics", "Windows OS", "Linux",
        "Troubleshooting", "Active Directory", "Remote Desktop", "Ticketing Tools",
        "Customer Service", "Hardware Installation"
    ],
    
    "Graphics Designer": [
        "Adobe Photoshop", "Illustrator", "Figma", "Canva", "UI/UX Design",
        "Typography", "Color Theory", "Wireframing", "Prototyping", "Adobe XD",
        "Creativity", "Brand Design"
    ]
}

# %%
df['skills'] = df['Career'].map(role_skills_detailed)

# %%
df.head()
# Out:
#    Programming  Machine Learning  Data Analysis  Cybersecurity  Networking  \
# 0            9                 6              7              6           7
# 1            5                 3              6             10          10
# 2            5                 3              6              6           7
# 3            8                 5             10              6           6
# 4            5                 6              3              9          10
#
#    UI/UX Design  Communication  Problem Solving  \
# 0             4              7               10
# 1             4              4                8
# 2             2              7                6
# 3             5              5                9
# 4             4              7                7
#
#                             Career  \
# 0                  Software tester
# 1              Networking Engineer
# 2     Application Support Engineer
# 3                  Software tester
# 4  Information Security Specialist
#
# ...

# %%
df.shape
# Out:
# (5000, 10)

# %%
df.describe()
# Out:
#        Programming  Machine Learning  Data Analysis  Cybersecurity  \
# count  5000.000000       5000.000000    5000.000000    5000.000000
# mean      6.842000          4.480800       5.886000       5.139600
# std       2.051896          2.128506       2.110804       2.541693
# min       2.000000          0.000000       2.000000       1.000000
# 25%       5.000000          3.000000       4.000000       3.000000
# 50%       7.000000          4.000000       6.000000       5.000000
# 75%       8.000000          6.000000       7.000000       7.000000
# max      10.000000         10.000000      10.000000      10.000000
#
#         Networking  UI/UX Design  Communication  Problem Solving
# count  5000.000000   5000.000000    5000.000000      5000.000000
# mean      5.900800      3.784200       6.314000         7.431400
# std       2.711536      2.113604       2.409017         1.666568
# min       1.000000      1.000000       2.000000         4.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Programming       5000 non-null   int64
#  1   Machine Learning  5000 non-null   int64
#  2   Data Analysis     5000 non-null   int64
#  3   Cybersecurity     5000 non-null   int64
#  4   Networking        5000 non-null   int64
#  5   UI/UX Design      5000 non-null   int64
#  6   Communication     5000 non-null   int64
#  7   Problem Solving   5000 non-null   int64
#  8   Career            5000 non-null   object
#  9   skills            5000 non-null   object
# dtypes: int64(8), object(2)
# memory usage: 390.8+ KB

# %%
df.corr(numeric_only=True)
# Out:
#                   Programming  Machine Learning  Data Analysis  Cybersecurity  \
# Programming          1.000000          0.369067       0.221599       0.092258
# Machine Learning     0.369067          1.000000       0.322534       0.098149
# Data Analysis        0.221599          0.322534       1.000000      -0.180368
# Cybersecurity        0.092258          0.098149      -0.180368       1.000000
# Networking           0.167065         -0.089787      -0.239290       0.592445
# UI/UX Design        -0.315057         -0.214909      -0.174554      -0.299471
# Communication       -0.487891         -0.241676      -0.026948      -0.365946
# Problem Solving      0.306750          0.239606       0.222109       0.007928
#
#                   Networking  UI/UX Design  Communication  Problem Solving
# Programming         0.167065     -0.315057      -0.487891         0.306750
# Machine Learning   -0.089787     -0.214909      -0.241676         0.239606
# ...

# %%
df["Career"].value_counts()
# Out:
# Career
# Application Support Engineer       339
# Networking Engineer                331
# AI ML Specialist                   330
# Software Developer                 327
# Information Security Specialist    320
# API Specialist                     319
# Technical Writer                   313
# Software tester                    313
# Cyber Security Specialist          312
# Graphics Designer                  310
# Helpdesk Engineer                  310
# Project Manager                    303
# Hardware Engineer                  300
# Business Analyst                   293
# Customer Service Executive         290
# Database Administrator             290
# Name: count, dtype: int64

# %%
df['Career'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Career'>

# %%
df.isnull().sum()
# Out:
# Programming         0
# Machine Learning    0
# Data Analysis       0
# Cybersecurity       0
# Networking          0
# UI/UX Design        0
# Communication       0
# Problem Solving     0
# Career              0
# skills              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Programming', 'Machine Learning', 'Data Analysis', 'Cybersecurity',
#        'Networking', 'UI/UX Design', 'Communication', 'Problem Solving',
#        'Career', 'skills'],
#       dtype='object')

# %%
df
# Out:
#       Programming  Machine Learning  Data Analysis  Cybersecurity  Networking  \
# 0               9                 6              7              6           7
# 1               5                 3              6             10          10
# 2               5                 3              6              6           7
# 3               8                 5             10              6           6
# 4               5                 6              3              9          10
# ...           ...               ...            ...            ...         ...
# 4995            5                 6              3              6           8
# 4996            7                 5              9              2           4
# 4997            9                 5              5              7          10
# 4998            8                 3              6             10           9
# 4999           10                 7              4              4           5
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X = df.drop(columns=['Career','skills'])
y = df['Career']

le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
for col in X.columns:
    if X[col].dtype == "object":
        X[col] = LabelEncoder().fit_transform(X[col].astype(str))

# %%
# Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
model = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=8,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="mlogloss"
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.764

# %%
import joblib

# %%
X.columns
# Out:
# Index(['Programming', 'Machine Learning', 'Data Analysis', 'Cybersecurity',
#        'Networking', 'UI/UX Design', 'Communication', 'Problem Solving'],
#       dtype='object')

# %%
joblib.dump(model,"model_role.pkl")
joblib.dump(X.columns.tolist(),"columns_role.pkl")
# Out:
# ['columns_role.pkl']
